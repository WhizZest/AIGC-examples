# %%
# 立即开始使用（使用默认女声模型）
from TTS.api import TTS

tts = TTS("tts_models/zh-CN/baker/tacotron2-DDC-GST")
tts.tts_to_file(
    text="语音合成技术真有趣，我已经安装成功了！",
    file_path="my_first_tts.wav"
)

print("✅ 第一个语音文件已生成: my_first_tts.wav")
# 在jupyter notebook中播放生成的音频
from IPython.display import Audio
Audio("my_first_tts.wav", autoplay=True)
# Out:
#  > tts_models/zh-CN/baker/tacotron2-DDC-GST is already downloaded.
#  > Using model: tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:C:\Users\Windows11\AppData\Local\tts\tts_models--zh-CN--baker--tacotron2-DDC-GST\scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
# c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\utils\io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\WINDOW~1\AppData\Local\Temp\jieba.cache
#  > Model's reduction rate `r` is set to: 2
#  > Text splitted to sentences.
# ['语音合成技术真有趣，我已经安装成功了！']
# Loading model cost 0.345 seconds.
# Prefix dict has been built successfully.
# y3in1 xø2ʈʂɵŋ2 dʑi4ʂu4 dʒœn1 io3tɕy4 ， wo3 i3dʑɨŋ1 an1dʒuɑŋ1 ʈʂɵŋ2goŋ1 lø5 ！
#  [!] Character 'g' not found in the vocabulary. Discarding it.
#  > Processing time: 1.8667078018188477
#  > Real-time factor: 0.4416406333702317
# ✅ 第一个语音文件已生成: my_first_tts.wav
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 在jupyter notebook中播放生成的音频
from IPython.display import Audio
Audio("my_first_tts.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from TTS.api import TTS
import torch
import numpy as np

# 加载支持GST的模型
tts = TTS("tts_models/zh-CN/baker/tacotron2-DDC-GST")

# 1. 基本控制：通过文本内容暗示风格
styles_by_text = {
    "中性": "系统正常运行，一切参数都在标准范围内。",
    "高兴": "太棒了！今天真是个令人兴奋的好日子！",
    "严肃": "请注意，这是一条重要通知，请务必仔细听。",
    "温和": "别担心，慢慢来，我会一直在这里帮助你。"
}

# 2. 高级控制：直接设置GST向量（细粒度控制）
def generate_with_style(text, style_vector=None, speaker_id=None):
    # 获取模型内部对象以访问低级API
    model = tts.synthesizer.tts_model
    model.eval()
    
    # 准备输入
    inputs = tts.synthesizer.tokenizer.text_to_ids(text, language="zh-cn")
    
    # 设置风格向量（GST）
    if style_vector is not None:
        if isinstance(style_vector, str):
            # 预设风格向量
            presets = {
                "happy": torch.randn(1, 1, 128) * 0.3 + 0.5,  # 高兴
                "serious": torch.randn(1, 1, 128) * 0.1 - 0.2,  # 严肃
                "neutral": torch.zeros(1, 1, 128),  # 中性
                "female": torch.randn(1, 1, 128) * 0.2 + 0.1,  # 偏女性
                "male": torch.randn(1, 1, 128) * 0.2 - 0.1,  # 偏男性
            }
            style_vector = presets.get(style_vector, presets["neutral"])
    
    # 合成语音
    with torch.no_grad():
        output = model.inference(inputs, style_vector=style_vector)
    
    return output["wav"]

# 生成不同风格的语音
for style_name, text in styles_by_text.items():
    output_file = f"reference_{style_name}.wav"
    tts.tts_to_file(text=text, file_path=output_file)
    print(f"生成 {style_name} 风格: {output_file}")
# Out:
#  > tts_models/zh-CN/baker/tacotron2-DDC-GST is already downloaded.
#  > Using model: tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:C:\Users\Windows11\AppData\Local\tts\tts_models--zh-CN--baker--tacotron2-DDC-GST\scale_stats.npy
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model's reduction rate `r` is set to: 2
#  > Text splitted to sentences.
# ['系统正常运行，一切参数都在标准范围内。']
#  > Processing time: 1.3888475894927979
#  > Real-time factor: 0.30986005897195434
# 生成 中性 风格: reference_中性.wav
#  > Text splitted to sentences.
# ['太棒了！', '今天真是个令人兴奋的好日子！']
# dʑin1tiɛn1 dʒœn1ʂʏ4 gø4 lɨŋ4ʐœn2ɕɨŋ1fœn4 dø5 xaʌ3ʐʏ4dzɪ5 ！
#  [!] Character 'g' not found in the vocabulary. Discarding it.
#  > Processing time: 1.247422456741333
#  > Real-time factor: 0.2841494335862231
# 生成 高兴 风格: reference_高兴.wav
#  > Text splitted to sentences.
# ['请注意，这是一条重要通知，请务必仔细听。']
#  > Processing time: 1.6220364570617676
#  > Real-time factor: 0.3457647320012759
# 生成 严肃 风格: reference_严肃.wav
#  > Text splitted to sentences.
# ['别担心，慢慢来，我会一直在这里帮助你。']
#  > Processing time: 1.3104071617126465
#  > Real-time factor: 0.3117391454747524
# 生成 温和 风格: reference_温和.wav

# %%
Audio("reference_中性.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("reference_高兴.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("reference_严肃.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("reference_温和.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from TTS.api import TTS
import os
os.environ["COQUI_TOS_AGREED"] = "1"

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")

# 不提供speaker_wav参数，使用内置默认声音
tts.tts_to_file(
    text="这是一个测试，使用XTTS的默认声音。",
    language="zh-cn",  # 仍然需要指定语言
    file_path="output_with_default_voice.wav"
)
print("✅ 使用默认声音生成完成")
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 has been updated, clearing model cache...
#  > Downloading model to C:\Users\Windows11\AppData\Local\tts\tts_models--multilingual--multi-dataset--xtts_v2
# 100%|██████████| 1.87G/1.87G [05:03<00:00, 6.16MiB/s]
# 4.37kiB [00:04, 935iB/s]
# 361kiB [00:04, 82.1kiB/s]
# 100%|██████████| 32.0/32.0 [00:07<00:00, 4.07iB/s]
#  89%|████████▊ | 6.87M/7.75M [00:00<00:00, 9.58MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
# 100%|██████████| 7.75M/7.75M [00:19<00:00, 9.58MiB/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       2 import os
#       3 os.environ["COQUI_TOS_AGREED"] = "1"
# ----> 5 tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")
#       7 # 不提供speaker_wav参数，使用内置默认声音
#       8 tts.tts_to_file(
#       9     text="这是一个测试，使用XTTS的默认声音。",
#      10     language="zh-cn",  # 仍然需要指定语言
#      11     file_path="output_with_default_voice.wav"
#      12 )
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\api.py:74, in TTS.__init__(self, model_name, model_path, config_path, vocoder_path, vocoder_config_path, progress_bar, gpu)
#      72 if model_name is not None and len(model_name) > 0:
#      73     if "tts_models" in model_name:
# ---> 74         self.load_tts_model_by_name(model_name, gpu)
#      75     elif "voice_conversion_models" in model_name:
#      76         self.load_vc_model_by_name(model_name, gpu)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\api.py:177, in TTS.load_tts_model_by_name(self, model_name, gpu)
#     171 model_path, config_path, vocoder_path, vocoder_config_path, model_dir = self.download_model_by_name(
#     172     model_name
#     173 )
#     175 # init synthesizer
#     176 # None values are fetch from the model
# --> 177 self.synthesizer = Synthesizer(
#     178     tts_checkpoint=model_path,
#     179     tts_config_path=config_path,
#     180     tts_speakers_file=None,
#     181     tts_languages_file=None,
#     182     vocoder_checkpoint=vocoder_path,
#     183     vocoder_config=vocoder_config_path,
#     184     encoder_checkpoint=None,
#     185     encoder_config=None,
#     186     model_dir=model_dir,
#     187     use_cuda=gpu,
#     188 )
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\utils\synthesizer.py:109, in Synthesizer.__init__(self, tts_checkpoint, tts_config_path, tts_speakers_file, tts_languages_file, vocoder_checkpoint, vocoder_config, encoder_checkpoint, encoder_config, vc_checkpoint, vc_config, model_dir, voice_dir, use_cuda)
#     107     self.output_sample_rate = self.tts_config.audio["sample_rate"]
#     108 else:
# --> 109     self._load_tts_from_dir(model_dir, use_cuda)
#     110     self.output_sample_rate = self.tts_config.audio["output_sample_rate"]
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\utils\synthesizer.py:161, in Synthesizer._load_tts_from_dir(self, model_dir, use_cuda)
#     156 def _load_tts_from_dir(self, model_dir: str, use_cuda: bool) -> None:
#     157     """Load the TTS model from a directory.
#     158
#     159     We assume the model knows how to load itself from the directory and there is a config.json file in the directory.
#     160     """
# --> 161     config = load_config(os.path.join(model_dir, "config.json"))
#     162     self.tts_config = config
#     163     self.tts_model = setup_tts_model(config)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\config\__init__.py:97, in load_config(config_path)
#      95 config_dict.update(data)
#      96 model_name = _process_model_name(config_dict)
# ---> 97 config_class = register_config(model_name.lower())
#      98 config = config_class()
#      99 config.from_dict(config_dict)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\config\__init__.py:40, in register_config(model_name)
#      38 # TODO: fix this
#      39 if model_name == "xtts":
# ---> 40     from TTS.tts.configs.xtts_config import XttsConfig
#      42     config_class = XttsConfig
#      43 paths = ["TTS.tts.configs", "TTS.vocoder.configs", "TTS.encoder.configs", "TTS.vc.configs"]
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\configs\xtts_config.py:5
#       2 from typing import List
#       4 from TTS.tts.configs.shared_configs import BaseTTSConfig
# ----> 5 from TTS.tts.models.xtts import XttsArgs, XttsAudioConfig
#       8 @dataclass
#       9 class XttsConfig(BaseTTSConfig):
#      10     """Defines parameters for XTTS TTS model.
#      11
#      12     Args:
#    (...)
#      65         >>> config = XttsConfig()
#      66     """
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\models\xtts.py:12
#      10 from TTS.tts.layers.xtts.gpt import GPT
#      11 from TTS.tts.layers.xtts.hifigan_decoder import HifiDecoder
# ---> 12 from TTS.tts.layers.xtts.stream_generator import init_stream_support
#      13 from TTS.tts.layers.xtts.tokenizer import VoiceBpeTokenizer, split_sentence
#      14 from TTS.tts.layers.xtts.xtts_manager import SpeakerManager, LanguageManager
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\layers\xtts\stream_generator.py:13
#      11 import torch.distributed as dist
#      12 from torch import nn
# ---> 13 from transformers import (
#      14     BeamSearchScorer,
#      15     ConstrainedBeamSearchScorer,
#      16     DisjunctiveConstraint,
#      17     GenerationConfig,
#      18     GenerationMixin,
#      19     LogitsProcessorList,
#      20     PhrasalConstraint,
#      21     PreTrainedModel,
#      22     StoppingCriteriaList,
#      23 )
#      24 from transformers.generation.utils import GenerateOutput, SampleOutput, logger
#      27 def setup_seed(seed):
#
# ImportError: cannot import name 'BeamSearchScorer' from 'transformers' (c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\transformers\__init__.py)

# %%
from TTS.api import TTS

# 1. 初始化模型（会自动下载预训练权重）
tts = TTS(model_name="tts_models/multilingual/multi-dataset/xtts_v2", progress_bar=True, gpu=True)

# 2. 零样本语音克隆合成
# 关键参数：
# - text: 要合成的目标文本
# - speaker_wav: 参考音频路径（用于克隆音色）
# - language: 目标文本的语言
output_path = "xtts.wav"
tts.tts_to_file(
    text="大家好，欢迎收听由人工智能生成的语音。",
    speaker_wav="reference_高兴.wav",  # 你的参考音频文件
    language="zh-cn",                     # 中文
    file_path=output_path
)
from IPython.display import Audio
Audio(output_path, autoplay=True)
# Out:
# c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\api.py:70: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 from TTS.api import TTS
#       3 # 1. 初始化模型（会自动下载预训练权重）
# ----> 4 tts = TTS(model_name="tts_models/multilingual/multi-dataset/xtts_v2", progress_bar=True, gpu=True)
#       6 # 2. 零样本语音克隆合成
#       7 # 关键参数：
#       8 # - text: 要合成的目标文本
#       9 # - speaker_wav: 参考音频路径（用于克隆音色）
#      10 # - language: 目标文本的语言
#      11 output_path = "xtts.wav"
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\api.py:74, in TTS.__init__(self, model_name, model_path, config_path, vocoder_path, vocoder_config_path, progress_bar, gpu)
#      72 if model_name is not None and len(model_name) > 0:
#      73     if "tts_models" in model_name:
# ---> 74         self.load_tts_model_by_name(model_name, gpu)
#      75     elif "voice_conversion_models" in model_name:
#      76         self.load_vc_model_by_name(model_name, gpu)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\api.py:177, in TTS.load_tts_model_by_name(self, model_name, gpu)
#     171 model_path, config_path, vocoder_path, vocoder_config_path, model_dir = self.download_model_by_name(
#     172     model_name
#     173 )
#     175 # init synthesizer
#     176 # None values are fetch from the model
# --> 177 self.synthesizer = Synthesizer(
#     178     tts_checkpoint=model_path,
#     179     tts_config_path=config_path,
#     180     tts_speakers_file=None,
#     181     tts_languages_file=None,
#     182     vocoder_checkpoint=vocoder_path,
#     183     vocoder_config=vocoder_config_path,
#     184     encoder_checkpoint=None,
#     185     encoder_config=None,
#     186     model_dir=model_dir,
#     187     use_cuda=gpu,
#     188 )
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\utils\synthesizer.py:109, in Synthesizer.__init__(self, tts_checkpoint, tts_config_path, tts_speakers_file, tts_languages_file, vocoder_checkpoint, vocoder_config, encoder_checkpoint, encoder_config, vc_checkpoint, vc_config, model_dir, voice_dir, use_cuda)
#     107     self.output_sample_rate = self.tts_config.audio["sample_rate"]
#     108 else:
# --> 109     self._load_tts_from_dir(model_dir, use_cuda)
#     110     self.output_sample_rate = self.tts_config.audio["output_sample_rate"]
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\utils\synthesizer.py:161, in Synthesizer._load_tts_from_dir(self, model_dir, use_cuda)
#     156 def _load_tts_from_dir(self, model_dir: str, use_cuda: bool) -> None:
#     157     """Load the TTS model from a directory.
#     158
#     159     We assume the model knows how to load itself from the directory and there is a config.json file in the directory.
#     160     """
# --> 161     config = load_config(os.path.join(model_dir, "config.json"))
#     162     self.tts_config = config
#     163     self.tts_model = setup_tts_model(config)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\config\__init__.py:97, in load_config(config_path)
#      95 config_dict.update(data)
#      96 model_name = _process_model_name(config_dict)
# ---> 97 config_class = register_config(model_name.lower())
#      98 config = config_class()
#      99 config.from_dict(config_dict)
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\config\__init__.py:40, in register_config(model_name)
#      38 # TODO: fix this
#      39 if model_name == "xtts":
# ---> 40     from TTS.tts.configs.xtts_config import XttsConfig
#      42     config_class = XttsConfig
#      43 paths = ["TTS.tts.configs", "TTS.vocoder.configs", "TTS.encoder.configs", "TTS.vc.configs"]
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\configs\xtts_config.py:5
#       2 from typing import List
#       4 from TTS.tts.configs.shared_configs import BaseTTSConfig
# ----> 5 from TTS.tts.models.xtts import XttsArgs, XttsAudioConfig
#       8 @dataclass
#       9 class XttsConfig(BaseTTSConfig):
#      10     """Defines parameters for XTTS TTS model.
#      11
#      12     Args:
#    (...)
#      65         >>> config = XttsConfig()
#      66     """
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\models\xtts.py:12
#      10 from TTS.tts.layers.xtts.gpt import GPT
#      11 from TTS.tts.layers.xtts.hifigan_decoder import HifiDecoder
# ---> 12 from TTS.tts.layers.xtts.stream_generator import init_stream_support
#      13 from TTS.tts.layers.xtts.tokenizer import VoiceBpeTokenizer, split_sentence
#      14 from TTS.tts.layers.xtts.xtts_manager import SpeakerManager, LanguageManager
#
# File c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\TTS\tts\layers\xtts\stream_generator.py:13
#      11 import torch.distributed as dist
#      12 from torch import nn
# ---> 13 from transformers import (
#      14     BeamSearchScorer,
#      15     ConstrainedBeamSearchScorer,
#      16     DisjunctiveConstraint,
#      17     GenerationConfig,
#      18     GenerationMixin,
#      19     LogitsProcessorList,
#      20     PhrasalConstraint,
#      21     PreTrainedModel,
#      22     StoppingCriteriaList,
#      23 )
#      24 from transformers.generation.utils import GenerateOutput, SampleOutput, logger
#      27 def setup_seed(seed):
#
# ImportError: cannot import name 'BeamSearchScorer' from 'transformers' (c:\Users\Windows11\anaconda3\envs\stylegan\lib\site-packages\transformers\__init__.py)
